# %%
import numpy as np
import matplotlib.pyplot as plt
data_19 = np.loadtxt('./rydberg_data/11_15/Energy_L1_19_den0.000_delta-10.0_5.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_kenneth_19 = np.loadtxt('./rydberg_data/11_15/data_19.csv',delimiter = ',')
data_17 = np.loadtxt('./rydberg_data/11_15/Energy_L1_17_den0.000_delta-10.0_5.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_kenneth_17 = np.loadtxt('./rydberg_data/11_15/data_17.csv',delimiter = ',')
data_15 = np.loadtxt('./rydberg_data/11_15/Energy_L1_15_den0.000_delta-10.0_5.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_kenneth_15 = np.loadtxt('./rydberg_data/11_15/data_15.csv',delimiter = ',')
data_11 = np.loadtxt('./rydberg_data/11_15/Energy_L1_11_den0.000_delta-20.0_10.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_kenneth_11 = np.loadtxt('./rydberg_data/11_15/data_11.csv',delimiter = ',')
data_21 = np.loadtxt('./rydberg_data/11_15/Energy_L1_21_den0.000_delta-10.0_5.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_22 = np.loadtxt('./rydberg_data/11_15/Energy_L1_22_den0.000_delta-10.0_5.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')

# %%
data_11_2 = np.loadtxt('./rydberg_data/11_18/AFM_Energy_L1_11_den0.000_delta-20.0_10.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_19_2 = np.loadtxt('./rydberg_data/11_18/AFM_Energy_L1_19_den0.000_delta-5.0_10.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_17_2 = np.loadtxt('./rydberg_data/11_18/AFM_Energy_L1_17_den0.000_delta-20.0_10.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_15_2 = np.loadtxt('./rydberg_data/11_18/AFM_Energy_L1_15_den0.000_delta-20.0_10.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')


data_15_3 =  np.loadtxt('./rydberg_data/11_26/AFM_Energy_L1_15_den0.000_delta-30.0_6.0_omega0.600_ramptime6.000_dt0.250_No0.csv', delimiter = ',')
data_19_3 =  np.loadtxt('./rydberg_data/11_26/AFM_Energy_L1_19_den0.000_delta-30.0_6.0_omega0.600_ramptime6.000_dt1.000_No0.csv', delimiter = ',')

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('19 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[2].plot(data_19_2[1],data_19_2[5],marker='o')
ax[2].set_xlabel('Detuning(MHz)')
ax[2].set_ylabel('Overlap <AFM|ground state>')
ax[1].plot(data_19[1], (data_19[3]-data_19[2])/2/np.pi,marker='o',label='line')
ax[1].plot(data_kenneth_19[0], data_kenneth_19[1],marker='+',label='Open circle')
ax[1].set_xlabel('Detuning(MHz)')
ax[1].set_ylabel('Energy gap(MHz)')
ax[1].legend()
ax[0].plot(data_19[1], data_19[4],marker='o',label='line')
ax[0].plot(data_kenneth_19[0], data_kenneth_19[2] ,marker='+',label='Open circle')
ax[0].set_xlabel('Detuning(MHz)')
ax[0].set_ylabel('Overlap <g^n|ground state>')
ax[0].legend()
ax[0].grid()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('17 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[2].plot(data_17_2[1],data_17_2[5],marker='o')
ax[2].set_xlabel('Detuning(MHz)')
ax[2].set_ylabel('Overlap <AFM|ground state>')

ax[1].plot(data_17[1], (data_17[3]-data_17[2])/2/np.pi,marker='o',label='line')
ax[1].plot(data_kenneth_17[0], data_kenneth_17[1],marker='+',label='Open circle')
ax[1].set_xlabel('Detuning(MHz)')
ax[1].set_ylabel('Energy gap(MHz)')
ax[1].legend()
ax[0].plot(data_17[1], data_17[4],marker='o',label='line')
ax[0].plot(data_kenneth_17[0], data_kenneth_17[2] ,marker='+',label='Open circle')
ax[0].set_xlabel('Detuning(MHz)')
ax[0].set_ylabel('Overlap <g^n|ground state>')
ax[0].legend()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('15 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[2].plot(data_15_2[1],data_15_2[5],marker='o')
ax[2].set_xlabel('Detuning(MHz)')
ax[2].set_ylabel('Overlap <AFM|ground state>')

ax[1].plot(data_15[1], (data_15[3]-data_15[2])/2/np.pi,marker='o',label='line')
ax[1].plot(data_kenneth_15[0], data_kenneth_15[1],marker='+',label='Open circle')
ax[1].set_xlabel('Detuning(MHz)')
ax[1].set_ylabel('Energy gap(MHz)')
ax[1].legend()
ax[0].plot(data_15[1], data_15[4],marker='o',label='line')
ax[0].plot(data_kenneth_15[0], data_kenneth_15[2] ,marker='+',label='Open circle')
ax[0].set_xlabel('Detuning(MHz)')
ax[0].set_ylabel('Overlap <g^n|ground state>')
ax[0].legend()

y =  (data_19_3[3]-data_19_3[2])/2/np.pi
t_id = np.argmin(y)
print(y)
print(t_id)
print(data_19_3[1][t_id])
print(y[t_id])
# print(np.transpose([data_15[1],(data_15[3]-data_15[2])/2/np.pi]))
# print(np.transpose([data_kenneth_15[0],data_kenneth_15[1]]))
# Out:
# [27.02718026 21.03511247 15.049535    9.08365088  3.24628796  1.75289083]
# 5
# 2.9999999999999987
# 1.7528908341019869

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('11 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[2].plot(data_11_2[1],data_11_2[5],marker='o')

ax[2].set_xlabel('Detuning(MHz)')
ax[2].set_ylabel('Overlap <AFM|ground state>')
ax[1].plot(data_11[1], (data_11[3]-data_11[2])/2/np.pi,marker='o',label='line')
#ax[1].plot(data_11_2[1], (data_11_2[3]-data_11[2])/2/np.pi,marker='o',label='2')

ax[1].plot(data_kenneth_11[0], data_kenneth_11[1],marker='+',label='Open circle')
ax[1].set_xlabel('Detuning(MHz)')
ax[1].set_ylabel('Energy gap(MHz)')
ax[1].legend()
ax[0].plot(data_11[1], data_11[4],marker='o',label='line')
#ax[0].plot(data_11_2[1], data_11_2[4],marker='o',label='2')

ax[0].plot(data_kenneth_11[0], data_kenneth_11[2] ,marker='+',label='Open circle')

ax[0].set_xlabel('Detuning(MHz)')
ax[0].set_ylabel('Overlap <g^n|ground state>')
ax[0].legend()

# %%
plt.subplots(figsize=(5,5))
#plt.plot(data_22[1], (data_22[3]-data_22[2])/2/np.pi,marker='+',label='22')
plt.plot(data_21[1], (data_21[3]-data_21[2])/2/np.pi,marker='+',label='21')

plt.plot(data_19[1], (data_19[3]-data_19[2])/2/np.pi,marker='+',label='19')
plt.plot(data_17[1], (data_17[3]-data_17[2])/2/np.pi,marker='+',label='17')
plt.plot(data_15[1], (data_15[3]-data_15[2])/2/np.pi,marker='o',label='15')
plt.plot(data_11[1], (data_11[3]-data_11[2])/2/np.pi,marker='o',label='11')
plt.legend()
plt.xlim([-5,5])
plt.ylim([0,5])
plt.xlabel('Detuning(MHz)')
plt.ylabel('Energy gap(MHz)')
# Out:
# Text(0, 0.5, 'Energy gap(MHz)')

# %%
data = []
id = 0
gap = []
detuning = []
plt.subplots(figsize=(10,10))
for i in (21,19,17,15,13):
    size = str(i)
    filename = './rydberg_data/11_16/Energy_L1_'+size+'_den0.000_delta-3.0_3.0_omega0.600_ramptime6.000_dt0.100_No0.csv'
    data.append(np.loadtxt(filename,delimiter = ',' ))
    gap.append((data[id][3]-data[id][2])/2/np.pi)
    detuning.append(data[id][1])
    plt.plot(data[id][1],(data[id][3]-data[id][2])/2/np.pi,marker='.',label=size)
    id = id + 1
plt.legend()
plt.xlabel('Detuning(MHz)')
plt.ylabel('Energy gap(MHz)')
# Out:
# Text(0, 0.5, 'Energy gap(MHz)')

# %%
cond = np.array([21,19,17,15,13])
for j in range(5):
    print('sites:'+str(cond[j]))
    print('detuning(MHz):'+str(round(detuning[j][np.argmin(gap[j])],4)))
    print('gap(MHz):'+str(round(np.min(gap[j]),4)))
# Out:
# sites:21
# detuning(MHz):1.25
# gap(MHz):0.2184
# sites:19
# detuning(MHz):1.25
# gap(MHz):0.2397
# sites:17
# detuning(MHz):1.25
# gap(MHz):0.2669
# sites:15
# detuning(MHz):1.15
# gap(MHz):0.2974
# sites:13
# detuning(MHz):1.15
# gap(MHz):0.3368

# %%
plt.plot(data_11[1],data_11[1])
plt.plot(data_11_2[1],data_11_2[1])
plt.plot(data_11_3[1],data_11_3[1])

# %%
# Out:
# array([-9.66666667, -9.        , -8.33333333, -7.66666667, -7.        ,
#        -6.33333333, -5.66666667, -5.        , -4.33333333, -3.66666667,
#        -3.        , -2.33333333, -1.66666667, -1.        , -0.33333333,
#         0.33333333,  1.        ,  1.66666667,  2.33333333,  3.        ,
#         3.66666667,  4.33333333,  5.        ,  5.66666667])

# %%
round(1.2346578,3)
# Out:
# 1.235
