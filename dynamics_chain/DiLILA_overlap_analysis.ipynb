# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_27_22_35_54_L15_1', delimiter = ',')
data_2 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_26_22_17_05_L15_1', delimiter = ',')

# %%
ig, ax = plt.subplots(2, 3, figsize=(15,5))
#fig.suptitle('19 Atoms')
MS = 1
LS = ''
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,2].plot(data[0],data[1],marker='o',markersize=MS,ls=LS)
ax[0,2].set_xlabel('t')
ax[0,2].set_ylabel('detuning')
ax[0,0].plot(data[0],data[2],marker='o',markersize=MS,ls=LS)
ax[0,0].set_xlabel('t')
ax[0,0].set_xlim([0,3])
ax[0,0].set_ylabel('overlap with GGG')
ax[0,1].plot(data[0],data[3],marker='o',markersize=MS,ls=LS)
ax[0,1].set_xlabel('t')
ax[0,1].set_ylabel('overlap with AFM')
ax[1,0].plot(data[0],data[4],marker='o',markersize=MS,ls=LS)
ax[1,0].set_xlabel('t')
ax[1,0].set_ylabel('overlap with Ground state')

ax[1,1].plot(data[0],data[5],marker='o',markersize=MS,ls=LS)
ax[1,1].set_xlabel('t')
ax[1,1].set_ylabel('overlap with 1st Excited state')

ax[1,2].plot(data[0],data[7],marker='o',markersize=MS,ls=LS)
ax[1,2].set_xlabel('t')
ax[1,2].set_ylabel('overlap with 3rd excited state')
# Out:
# Text(0, 0.5, 'overlap with 3rd excited state')

# %%
data1 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_27_01_01_24_L19_1', delimiter = ',')
data3 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_27_00_13_33_L19_1', delimiter = ',')
data2 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_26_22_29_09_L19_1', delimiter = ',')



fig, ax = plt.subplots(2, 2, figsize=(10,10))
#fig.suptitle('19 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,1].plot(data1[0],data1[1],marker='o',markersize=MS,ls=LS,label = 'T =30us ')
ax[0,1].plot(data2[0],data2[1],marker='o',markersize=MS,ls=LS,label = 'T =16us ')
ax[0,1].plot(data3[0],data3[1],marker='o',markersize=MS,ls=LS,label = 'T =6us ')
MS =1
LS = 'solid'
# ax[0,2].set_xlabel('t')
# ax[0,2].set_ylabel('detuning')
# ax[0,0].plot(data1[0],data1[2],marker='o',markersize=MS,ls=LS)
# ax[0,0].plot(data2[0],data2[2],marker='o',markersize=MS,ls=LS)
# ax[0,0].plot(data3[0],data3[2],marker='o',markersize=MS,ls=LS)

ax[0,1].set_xlabel('t(us)')
ax[0,1].set_ylabel('detuning(MHz)')
# ax[0,1].plot(data1[0],data1[3],marker='o',markersize=MS,ls=LS)
# ax[0,1].set_xlabel('t')
# ax[0,1].set_ylabel('overlap with AFM')
ax[0,0].plot(data1[0],data1[4],marker='o',markersize=MS,ls=LS)
ax[0,0].plot(data2[0],data2[4],marker='o',markersize=MS,ls=LS)
ax[0,0].plot(data3[0],data3[4],marker='.',markersize=MS,ls=LS)
ax[0,0].set_xlabel('t(us)')
ax[0,0].set_ylabel('Overlap with the ground state')

o1 = data1[4][int(len(data1[4])/2)]
o2 = data2[4][int(len(data2[4])/2)]
o3 = data3[4][int(len(data3[4])/2)]
fig.legend()
print('The overlap of the evolved state with the system ground state at the critical point:')
print('T = 30us '+str(round(o1,4)))
print('T = 16us '+str(round(o2,4)))
print('T = 6us '+str(round(o2,4)))
# ax[1,0].set_xlabel('t')
# ax[1,0].set_ylabel('overlap with Ground state')

# ax[1,1].plot(data1[0],data1[5],marker='o',markersize=MS,ls=LS)
# ax[1,1].set_xlabel('t')
# ax[1,1].set_ylabel('overlap with 1st Excited state')
# ax[1,2].plot(data1[0],data1[6],marker='o',markersize=MS,ls=LS)
# ax[1,2].set_xlabel('t')
# ax[1,2].set_ylabel('overlap with 2nd excited state')
# Out:
# The overlap of the evolved state with the system ground state at the critical point:
# T = 30us 0.7745
# T = 16us 0.7741
# T = 6us 0.7741

# %%
fig, ax = plt.subplots(2, 2, figsize=(10,10))
#fig.suptitle('19 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,1].plot(data[0],data[1],marker='o',markersize=MS,ls=LS,label = 'Initial Detuning =-20MHz ')
ax[0,1].plot(data_2[0],data_2[1],marker='o',markersize=MS,ls=LS,label = 'Initial Detuning =-10MHz ')
MS =1
LS = 'solid'

ax[0,1].set_xlabel('t(us)')
ax[0,1].set_ylabel('detuning(MHz)')

ax[0,0].plot(data[0],data[4],marker='o',markersize=MS,ls=LS)
ax[0,0].plot(data_2[0],data_2[4],marker='o',markersize=MS,ls=LS)
ax[0,0].set_xlabel('t(us)')
ax[0,0].set_ylabel('Overlap with the ground state')

o1 = data[4][int(len(data1[4])/2)]
o1 = data[4][0]
o2 = data_2[4][int(len(data_2[4])/2)]
o2 = data_2[4][0]
fig.legend()
print('The overlap of the evolved state with the system ground state at the critical point:')
print('Initial Detuning =-20MHz '+str(round(o1,4)))
print('Initial Detuning =-10MHz '+str(round(o2,4)))
# Out:
# The overlap of the evolved state with the system ground state at the critical point:
# Initial Detuning =-20MHz 0.9482
# Initial Detuning =-10MHz 0.8176

# %%
data_19_30 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_28/Overlap2022_11_28_00_09_07_L19_1', delimiter = ',')
data_19_10 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_27_00_13_33_L19_1', delimiter = ',')
fig, ax = plt.subplots(2, 2, figsize=(10,10))
#fig.suptitle('19 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,1].plot(data_19_30[0],data_19_30[1],marker='o',markersize=MS,ls=LS,label = 'Initial Detuning =-30MHz ')
ax[0,1].plot(data_19_10[0],data_19_10[1],marker='o',markersize=MS,ls=LS,label = 'Initial Detuning =-10MHz ')
MS =1
LS = 'solid'

ax[0,1].set_xlabel('t(us)')
ax[0,1].set_ylabel('detuning(MHz)')

ax[0,0].plot(data_19_30[0],data_19_30[4],marker='o',markersize=MS,ls=LS)
ax[0,0].plot(data_19_10[0],data_19_10[4],marker='o',markersize=MS,ls=LS)
ax[0,0].set_xlabel('t(us)')
ax[0,0].set_ylabel('Overlap with the ground state')

o1 = data_19_30[4][int(len(data_19_30[4])/2)]
o2 = data_19_10[4][int(len(data_19_10[4])/2)]
fig.legend()
print('The overlap of the evolved state with the system ground state at the critical point:')
print('Initial Detuning =-30MHz '+str(round(o1,4)))
print('Initial Detuning =-10MHz '+str(round(o2,4)))
# Out:
# The overlap of the evolved state with the system ground state at the critical point:
# Initial Detuning =-30MHz 0.8458
# Initial Detuning =-10MHz 0.7754

# %%
data_test = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_29/Overlap2022_11_30_14_19_15_L15_1', delimiter = ',')
fig, ax = plt.subplots(2, 2, figsize=(10,10))
plt.subplots_adjust(wspace=0.5,hspace=0.5)
MS =1
LS = 'solid'
ax[0,1].plot(data_test[0],data_test[1],marker='o',markersize=MS,ls=LS,label = 'T =30us ')


ax[0,1].set_xlabel('t(us)')
ax[0,1].set_ylabel('detuning(MHz)')

ax[0,0].plot(data_test[0],data_test[4],marker='o',markersize=MS,ls=LS)

ax[0,0].set_xlabel('t(us)')
ax[0,0].set_ylabel('Overlap with the ground state')

o1 = data_test[4][0]

fig.legend()
print('The overlap of the evolved state with the system ground state at the beginning point:')
print(str(round(o1,5)))
# Out:
# The overlap of the evolved state with the system ground state at the beginning point:
# 0.94836
