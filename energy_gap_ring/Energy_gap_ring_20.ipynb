# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_14/gap2022_12_15_16_14_21_ring_L20_263', delimiter = ',')
data_6 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_14/gap2022_12_15_16_14_18_ring_L20_813', delimiter = ',')
data_7 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_14/gap2022_12_15_16_14_18_ring_L20_564', delimiter = ',')
data_7_2 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_14/gap2022_12_15_15_52_42_ring_L20', delimiter = ',')
data_9 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_02_25_49_ring_L20_580', delimiter = ',')
data_12 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_02_25_52_ring_L20_44', delimiter = ',')
data_18 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_02_25_52_ring_L20_527', delimiter = ',')
data_15_2 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_02_26_19_ring_L20_914', delimiter = ',')

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('20 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[2].plot(data_6[1],data_6[5],marker='o',label='V = 6')
ax[2].plot(data_7[1],data_7[5],marker='o',label='V = 7')

ax[2].plot(data[1],data[5],marker='o',label='V = 8')
ax[2].plot(data_9[1],data_9[5],marker='o',label='V = 9')
ax[2].plot(data_12[1],data_12[5],marker='o',label='V = 12')
ax[2].plot(data_15_2[1],data_15_2[5],marker='o',label='V = 15')
ax[2].plot(data_18[1],data_18[5],marker='o',label='V = 18')

ax[2].legend()


ax[2].set_xlabel('Detuning(MHz)')
ax[2].set_ylabel('Overlap <AFM|ground state>')

ax[1].plot(data_6[1], (data_6[6]-data_6[2])/2/np.pi,marker='o',label='V = 6')
ax[1].plot(data_7_2[1], (data_7_2[6]-data_7_2[2])/2/np.pi,marker='o',label='V = 7')
ax[1].plot(data[1], (data[6]-data[2])/2/np.pi,marker='o',label='V = 8')
ax[1].plot(data_9[1], (data_9[6]-data_9[2])/2/np.pi,marker='o',label='V = 9')
ax[1].plot(data_12[1], (data_12[6]-data_12[2])/2/np.pi,marker='o',label='V = 12')
ax[1].plot(data_18[1], (data_18[6]-data_18[2])/2/np.pi,marker='o',label='V = 18')
ax[1].plot(data_15_2[1], (data_15_2[6]-data_15_2[2])/2/np.pi,marker='o',label='V = 15')
ax[1].plot(data_10[1], (data_10[6]-data_10[2])/2/np.pi,marker='o',label='V = 10')

ax[1].set_xlabel('Detuning(MHz)')
#ax[1].set_xlim([-1,4])
ax[1].set_ylabel('Energy gap(MHz)')
ax[1].legend()
ax[0].plot(data[1], data[4],marker='o',label='line')
ax[0].set_xlabel('Detuning(MHz)')
ax[0].set_ylabel('Overlap <g^n|ground state>')
ax[0].legend()
ax[0].grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-755f9fa9e165> in <module>
#      24 ax[1].plot(data_18[1], (data_18[6]-data_18[2])/2/np.pi,marker='o',label='V = 18')
#      25 ax[1].plot(data_15_2[1], (data_15_2[6]-data_15_2[2])/2/np.pi,marker='o',label='V = 15')
# ---> 26 ax[1].plot(data_10[1], (data_10[6]-data_10[2])/2/np.pi,marker='o',label='V = 10')
#      27
#      28 ax[1].set_xlabel('Detuning(MHz)')
#
# NameError: name 'data_10' is not defined

# %%
#    op_list1 = ['t','Detuning','E0','E1','overlap_g','overlap_afm','E2','E3']
ms = 2
ls = '-'
fig, ax = plt.subplots(2, 3, figsize=(15,10))
fig.suptitle('20 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,0].plot(data[0],data[1],marker='o',markersize = ms,ls = ls)
ax[0,0].set_xlabel('t(us)')
ax[0,0].set_ylabel('detuning(MHz)')

ax[0,1].plot(data[1],data[2]/2/np.pi,marker='o',markersize = ms,ls = ls,label= 'Ground state')
ax[0,1].set_ylabel('Energy(MHz)')
ax[0,1].set_xlabel('detuning(MHz)')
ax[0,1].legend()

ax[0,2].plot(data[1],data[3]/2/np.pi-data[2]/2/np.pi,marker='o',markersize = ms,ls = ls,label= '1st state gap')
ax[0,2].plot(data[1],data[6]/2/np.pi-data[2]/2/np.pi,marker='o',markersize = ms,ls = ls,label= '2nd state gap')
ax[0,2].plot(data[1],data[7]/2/np.pi-data[2]/2/np.pi,marker='o',markersize = ms,ls = ls,label= '3nd state gap')
ax[0,2].set_ylabel('Energy(MHz)')
ax[0,2].set_xlabel('detuning(MHz)')
ax[0,2].legend()

ax[1,0].plot(data[1],data[4],marker='o',markersize = ms,ls = ls)
ax[1,0].set_xlabel('Detuning(MHz)')
ax[1,0].set_ylabel('Overlap <g^n|ground state>')

ax[1,1].plot(data[1],2*data[5],marker='o',markersize = ms,ls = ls)
ax[1,1].set_xlabel('Detuning(MHz)')
ax[1,1].set_ylabel('Overlap <AFM|ground state>')
print(data[1],data[3]/2/np.pi-data[2]/2/np.pi)
# Out:
# [-5.  -4.2 -3.4 -2.6 -1.8 -1.  -0.2  0.6  1.4  2.2  3.   3.8  4.6  5.4
#   6.2  7.   7.8  8.6  9.4 10.2 11.  11.8 12.6 13.4 14.2] [5.24033991e+00 4.48201260e+00 3.73877051e+00 3.01843115e+00
#  2.33264613e+00 1.69579049e+00 1.11824275e+00 5.97576038e-01
#  1.36694352e-01 2.11267818e-03 4.00589219e-05 1.97244299e-06
#  2.08938758e-07 2.45045371e-08 7.84105225e-09 3.79715459e-09
#  2.67016276e-09 2.67300493e-09 3.80882170e-09 7.86840815e-09
#  2.45541116e-08 1.24344467e-07 2.69368418e-06 6.06698572e-05
#  3.59429202e-03]

# %%
plt.plot(delta, f_data)

# %%
 np.linspace(-6,8,30)
# Out:
# array([-6.        , -5.51724138, -5.03448276, -4.55172414, -4.06896552,
#        -3.5862069 , -3.10344828, -2.62068966, -2.13793103, -1.65517241,
#        -1.17241379, -0.68965517, -0.20689655,  0.27586207,  0.75862069,
#         1.24137931,  1.72413793,  2.20689655,  2.68965517,  3.17241379,
#         3.65517241,  4.13793103,  4.62068966,  5.10344828,  5.5862069 ,
#         6.06896552,  6.55172414,  7.03448276,  7.51724138,  8.        ])

# %%
data = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_14/AFM_Energy_L8_1_den0.000_delta-10.0_20.0_omega1.950_ramptime10.000_dt0.100_No0.csv', delimiter = ',')

fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('8 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[2].plot(data[1],data[5],marker='o')
ax[2].set_xlabel('Detuning(MHz)')
ax[2].set_ylabel('Overlap <AFM|ground state>')
# ax[1].plot(data[1], data[2]/2/np.pi,marker='o',label='0th')

# ax[1].plot(data[1], data[3]/2/np.pi,marker='o',label='1st')
# ax[1].plot(data[1], data[6]/2/np.pi,marker='o',label='2nd')
ax[1].plot(data[1], (data[6]-data[2])/2/np.pi,marker='+',label='gap 2')
#ax[1].plot(data[1], (data[7]-data[2])/2/np.pi,marker='+',label='gap 3')

ax[1].plot(np.linspace(-6,8,30), f_2nd_NN_ring_geo,marker = 'o')
ax[1].set_xlabel('Detuning(MHz)')
ax[1].set_ylabel('Energy (MHz)')
ax[1].set_xlim([-6,8])
ax[1].set_ylim([0,10])
ax[1].legend()
ax[0].plot(data[1], data[4],marker='o',label='line')
ax[0].set_xlabel('Detuning(MHz)')
ax[0].set_ylabel('Overlap <g^n|ground state>')
ax[0].legend()
ax[0].grid()

# %%
f_data8_2nd = np.array([6.37622773, 5.92346033, 5.47670007, 5.03813619, 4.60316746 ,4.17895669,
 3.76435134, 3.35999983, 2.98043768, 2.61745215, 2.28065153 ,1.97447336,
 1.70655828 ,1.48502399, 1.32010498, 1.23939968, 1.26718195, 1.29511839,
 1.51909125, 1.87106676, 2.28766699, 2.73400223, 3.19181972, 3.66631419,
 4.13451368 ,4.61490466, 5.09010824, 5.55991685, 6.03575871, 6.51395581])

# %%
f_data_1st = np.loadtxt('C:/Users/wangy/Downloads/test.txt', delimiter = ' ')
f_data_3rd = np.array([6.37824325, 5.92640454 ,5.47952028, 5.04107434, 4.6041305 , 4.17941307,
 3.76479513, 3.36427571, 2.98062877, 2.61796226 ,2.28073063, 1.97466203,
 1.70663767, 1.4857519,  1.32276877, 1.24103648, 1.26748531, 1.43596592,
 1.73050352 ,2.10422926, 2.52071799 ,2.96021339 ,3.40595331 ,3.87227523,
 4.33569724 ,4.80263727, 5.27021887 ,5.73814082 ,6.20605059, 6.67332026])
f_data_2nd_ED = np.array([6.37824319, 5.92640371, 5.4793563 , 5.03815435, 4.60413003, 4.17896835,
3.76479266, 3.36425592, 2.98062722 ,2.61786399 ,2.28067892, 1.97466016,
 1.7065813,  1.48514897 ,1.32275456, 1.23945447, 1.26748183, 1.29513413,
 1.51881565, 1.87089597, 2.28688364, 2.73371219, 3.19568479, 3.6651191,
 4.13805122, 4.6123248,  5.08670476 ,5.56044317, 6.03305494, 6.50419607])
f_2nd_NNNN = np.array([6.38021512, 5.92865593 ,5.48194566 ,5.04115138 ,4.60762209, 4.18306264,
 3.76961862, 3.36996524, 2.98738913, 2.62585311, 2.29005494 ,1.98554682,
 1.71907082, 1.49938794, 1.33919191 ,1.25925446, 1.29250822 ,1.3180068,
 1.54897527 ,1.90545134, 2.32421301, 2.77297849, 3.23640788, 3.70698976,
 4.18085337, 4.65589937 ,5.13093075, 5.60522649, 6.07832139, 6.5498865])
f_2nd_NN_ring_geo = np.array([6.3852305,  5.93429288, 5.48830467, 5.04834658, 4.61577774 ,4.1923033,
 3.78004675, 3.38161571, 3.00014289, 2.63928166, 2.30315368, 1.99629728,
 1.7237415 , 1.49138462, 1.30691827, 1.18192843, 1.13636077 ,1.19700222,
 1.26321449 ,1.51294442 ,1.87047583,2.28300573 ,2.72351401 ,3.17869734,
 3.64171948 ,4.10885986, 4.57797711, 5.04777007, 5.51740147, 5.98629581])

# %%
plt.plot(np.linspace(-6,8,30),f_data_2nd_ED,marker= 'o')
plt.plot(np.linspace(-6,8,30),f_data_1st,marker= 'o')
plt.plot(np.linspace(-6,8,30),f_data_3rd,marker= 'o')
plt.plot(np.linspace(-6,8,30),f_2nd_NN_ring_geo,marker= 'o')

# %%
plt.plot(data_10[1],data_10[7]-data_10[2],marker = 'o',label = '3')

# %%
np.transpose(np.array([data_10[1], (data_10[6]-data_10[2])/2/np.pi]))
# Out:
# array([[0.        , 1.04320371],
#        [0.035     , 1.02168832],
#        [0.07      , 1.00036021],
#        [0.105     , 0.9792233 ],
#        [0.14      , 0.95828184],
#        [0.175     , 0.93754048],
#        [0.21      , 0.91700429],
#        [0.245     , 0.8966788 ],
#        [0.28      , 0.87657005],
#        [0.315     , 0.85668467],
#        [0.35      , 0.83702985],
#        [0.385     , 0.81761349],
#        [0.42      , 0.79844423],
#        [0.455     , 0.77953149],
#        [0.49      , 0.7608856 ],
#        [0.525     , 0.74251785],
#        [0.56      , 0.72444057],
#        [0.595     , 0.70666729],
#        [0.63      , 0.6892128 ],
#        [0.665     , 0.67209329],
#        [0.7       , 0.65532653],
#        [0.735     , 0.63893197],
#        [0.77      , 0.62293101],
#        [0.805     , 0.60734713],
#        [0.84      , 0.59220623],
#        [0.875     , 0.57753684],
#        [0.91      , 0.56337055],
#        [0.945     , 0.54974238],
# ...

# %%
data[1]
# Out:
# array([-10. ,  -9.7,  -9.4,  -9.1,  -8.8,  -8.5,  -8.2,  -7.9,  -7.6,
#         -7.3,  -7. ,  -6.7,  -6.4,  -6.1,  -5.8,  -5.5,  -5.2,  -4.9,
#         -4.6,  -4.3,  -4. ,  -3.7,  -3.4,  -3.1,  -2.8,  -2.5,  -2.2,
#         -1.9,  -1.6,  -1.3,  -1. ,  -0.7,  -0.4,  -0.1,   0.2,   0.5,
#          0.8,   1.1,   1.4,   1.7,   2. ,   2.3,   2.6,   2.9,   3.2,
#          3.5,   3.8,   4.1,   4.4,   4.7,   5. ,   5.3,   5.6,   5.9,
#          6.2,   6.5,   6.8,   7.1,   7.4,   7.7,   8. ,   8.3,   8.6,
#          8.9,   9.2,   9.5,   9.8,  10.1,  10.4,  10.7,  11. ,  11.3,
#         11.6,  11.9,  12.2,  12.5,  12.8,  13.1,  13.4,  13.7,  14. ,
#         14.3,  14.6,  14.9,  15.2,  15.5,  15.8,  16.1,  16.4,  16.7,
#         17. ,  17.3,  17.6,  17.9,  18.2,  18.5,  18.8,  19.1,  19.4,
#         19.7])

# %%
data[1]
# Out:
# array([-10. ,  -8.8,  -7.6,  -6.4,  -5.2,  -4. ,  -2.8,  -1.6,  -0.4,
#          0.8,   2. ,   3.2,   4.4,   5.6,   6.8,   8. ,   9.2,  10.4,
#         11.6,  12.8,  14. ,  15.2,  16.4,  17.6,  18.8])

# %%
(data[6]-data[2])/2/np.pi
# Out:
# array([10.12933978,  8.94747536,  7.77123407,  6.60352672,  5.44948639,
#         4.31872563,  3.2300968 ,  2.21968663,  1.34176847,  0.64743484,
#         0.48551017,  1.638431  ,  2.88599714,  4.11649159,  5.32933787,
#         6.52725596,  7.71148508,  8.88151302, 10.03492055, 11.16675178,
#        12.26801375, 13.32247847, 14.29997343, 15.14299736, 15.74707535])

# %%
8*5.575/9.4
# Out:
# 4.74468085106383

# %%
# Find the critical point, fine sweep 
data_10 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_13_27_44_ring_L20_69', delimiter = ',')
data_18 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_13_27_44_ring_L20_764', delimiter = ',')
data_12 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_13_27_44_ring_L20_555', delimiter = ',')
data_15 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_16/gap2022_12_16_13_27_44_ring_L20_541', delimiter = ',')
V = np.array([10,12,15,18])
data = np.array([data_10[1],(data_10[6]-data_10[2])/2/np.pi,(data_12[6]-data_12[2])/2/np.pi,(data_15[6]-data_15[2])/2/np.pi,(data_18[6]-data_18[2])/2/np.pi])

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
fig.suptitle('20 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[1].plot(data_10[1], (data_10[6]-data_10[2])/2/np.pi,marker='o',label='V = 10',ms = 2)
ax[1].plot(data_12[1], (data_12[6]-data_12[2])/2/np.pi,marker='o',label='V = 12',ms = 2)

ax[1].plot(data_15[1], (data_15[6]-data_15[2])/2/np.pi,marker='o',label='V = 15',ms = 2)
ax[1].plot(data_18[1], (data_18[6]-data_18[2])/2/np.pi,marker='o',label='V = 18',ms = 2)
ax[1].set_xlabel('Detuning(MHz)')
#ax[1].set_xlim([-1,4])
ax[1].set_ylabel('Energy gap(MHz)')
ax[1].legend()
crit_d_list = []
crit_gap_list = []
for i in range(1,len(data)):
    gap = data[i]
    crit_gap = (np.min(data[i]))
    crit_d = (data[0,np.argmin(data[i])])
    ax[0].scatter(crit_d,crit_gap,label = 'V = '+str(V[i-1]))
    ax[0].legend()
    ax[0].grid('true')
ax[0].set_xlabel('Critical detuning(MHz)')
ax[0].set_ylabel('Critical gap(MHz)')
# Out:
# Text(0, 0.5, 'Critical gap(MHz)')

# %%
crit_d = []
crit_gap = []
for i in range(1,len(data)):
    gap = data[i]
    crit_gap.append(np.min(data[i]))
    crit_id = np.argmin(data[i])
    crit_d.append(data[0,crit_id])

# %%
# Out:
# [1.5750000000000002, 1.6100000000000003, 1.645, 1.7150000000000003]

# %%
np.argmin(data[1])
# Out:
# 45
