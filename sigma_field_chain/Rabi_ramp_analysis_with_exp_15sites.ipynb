# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_sim_5 = np.array([[0.5951805960810617, 0.23911029903173364, 0.12968850394768017, 0.10097176593057389, 0.11357865556995173, 0.1633688221552737, 0.26309830556612157],
[0.6142233601073186, 0.2722199291705787, 0.1608011420398372, 0.13022577522047712, 0.13935446557568215, 0.18154298400137725, 0.2930337744124466],
[0.6317930575904223, 0.3034806746090086, 0.20354841858114248, 0.1812994617523021, 0.19709495153241002, 0.24607593086099872, 0.35242153954411715],
[0.6550560030203355, 0.34218806171363986, 0.261560078179685, 0.2523145932092947, 0.27430381971547546, 0.3145905355281846, 0.3999510689290253],
[0.6729198899585291, 0.3737571175331867, 0.29627489416897035, 0.2854111889328379, 0.2996425818207878, 0.33357896052563085, 0.41933170949317605],
[0.9609899480576709, 0.9159378290305376, 0.9016327899689801, 0.8898133800823463, 0.884246877004091, 0.8869111567030044, 0.9030642298542128],])

# %%
data_exp5 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_1/expdata20221130163625.csv',delimiter=',')

# %%
# 5us ramp 
MS =10
fig,ax = plt.subplots(ncols=3,nrows=2,figsize=(15,7))
time = np.array([2.2, 3.1-0.6, 3.4-0.6, 3.1, 4-0.6,  5.])
plt.subplots_adjust(wspace=0.5,hspace=0.5)
for i in range(6):
    print(i)
    zz_exp = data_exp5[2  +i]
    zz_err_exp = data_exp5[2+i+7]
    print(time[i])
    print('exp')
    print(zz_exp)
    print('sim')
    print(data_sim_5[i])
    ax[i//3,i%3].scatter(2*data_exp5[0],zz_exp,label = 'Exp' )
    ax[i//3,i%3].scatter(2*data_exp5[0],data_sim_5[i],label = 'Sim')
    ax[i//3,i%3].plot(2*data_exp5[0],zz_exp)
    #ax[i//3,i%3].text(9.5,0.7,str(time[i])+'us')
    ax[i//3,i%3].set_yscale('log')
    ax[i//3,i%3].legend(loc = 'upper right')
   #ax[i//3,i%3].set_ylim((0.01,1))
    ax[i//3,i%3].set_xlabel('d')
    ax[i//3,i%3].set_ylabel('$\langle \sigma_{mid-d/2} \sigma_{mid+d/2} \\rangle$ at '+str(time[i])+'us',fontsize= 12,rotation = 0)
    ax[i//3,i%3].yaxis.set_label_coords(0.15,1.02)
    ax[i//3,i%3].set_xticks(2*data_exp5[0])
ax[0,2].text(9,0.7,'Critical point')
plt.suptitle('correlator of the sigma field for a 5us Dilila ramp with a 600ns Rabi ramp')
# Out:
# 0
# 2.2
# exp
# [0.38     0.073333 0.02     0.06     0.14     0.22     0.34667 ]
# sim
# [0.5951806  0.2391103  0.1296885  0.10097177 0.11357866 0.16336882
#  0.26309831]
# 1
# 2.5
# exp
# [0.42949  0.16026  0.083333 0.032051 0.089744 0.16026  0.25    ]
# sim
# [0.61422336 0.27221993 0.16080114 0.13022578 0.13935447 0.18154298
#  0.29303377]
# 2
# 2.8
# exp
# [0.43624 0.22148 0.16779 0.10738 0.16107 0.16107 0.24832]
# sim
# [0.63179306 0.30348067 0.20354842 0.18129946 0.19709495 0.24607593
#  0.35242154]
# 3
# 3.1
# exp
# [0.55782 0.27211 0.12245 0.15646 0.17007 0.16327 0.26531]
# sim
# [0.655056   0.34218806 0.26156008 0.25231459 0.27430382 0.31459054
#  0.39995107]
# 4
# 3.4
# exp
# [0.41549  0.16901  0.14789  0.084507 0.077465 0.19014  0.38732 ]
# sim
# [0.67291989 0.37375712 0.29627489 0.28541119 0.29964258 0.33357896
#  0.41933171]
# 5
# 5.0
# exp
# [0.72078 0.48701 0.38312 0.37662 0.2987  0.31169 0.42857]
# sim
# ...

# %%
data_sim_3 = np.array([[0.5951805960810617, 0.23911029903173364, 0.12968850394768017, 0.10097176593057389, 0.11357865556995173, 0.1633688221552737, 0.26309830556612157],
[0.6142233601073186, 0.2722199291705787, 0.1608011420398372, 0.13022577522047712, 0.13935446557568215, 0.18154298400137725, 0.2930337744124466],
[0.6317930575904223, 0.3034806746090086, 0.20354841858114248, 0.1812994617523021, 0.19709495153241002, 0.24607593086099872, 0.35242153954411715],
[0.6550560030203355, 0.34218806171363986, 0.261560078179685, 0.2523145932092947, 0.27430381971547546, 0.3145905355281846, 0.3999510689290253],
[0.6729198899585291, 0.3737571175331867, 0.29627489416897035, 0.2854111889328379, 0.2996425818207878, 0.33357896052563085, 0.41933170949317605],
[0.9609899480576709, 0.9159378290305376, 0.9016327899689801, 0.8898133800823463, 0.884246877004091, 0.8869111567030044, 0.9030642298542128]])

data_exp3 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_1/expdata20221130181132.csv',delimiter=',')

# %%
# 3us ramp 
MS =10
fig,ax = plt.subplots(ncols=3,nrows=2,figsize=(15,7))
time = np.array([1.34,1.51,1.68,1.85,2.02,3.00])
plt.subplots_adjust(wspace=0.5,hspace=0.5)
for i in range(6):
    zz_exp = data_exp3[2+i]
    print(zz_exp)
    zz_err_exp = data_exp3[2+i+7]
    print(data_sim_3[i])
    ax[i//3,i%3].scatter(2*data_exp3[0],zz_exp,label = 'exp' )
    ax[i//3,i%3].scatter(2*data_exp3[0],data_sim_3[i],label = 'sim')
    ax[i//3,i%3].plot(2*data_exp3[0],zz_exp)

   # ax[i//3,i%3].set_yscale('log')
    ax[i//3,i%3].legend(loc = 'upper right')
    ax[i//3,i%3].set_ylim((0.001,1))
    ax[i//3,i%3].set_xticks(2*data_exp3[0])
    ax[i//3,i%3].yaxis.set_label_coords(0.15,1.02)

    ax[i//3,i%3].set_ylabel('$\langle \sigma_{mid-d/2} \sigma_{mid+d/2} \\rangle$ at '+str(time[i])+'us',fontsize= 12,rotation = 0)

ax[0,2].text(9,0.7,'Critical point')


plt.suptitle('correlator of the sigma field for a 3us Dilila ramp with a 600ns Rabi ramp')
# Out:
# [0.42453 0.16981 0.12264 0.      0.16981 0.24528 0.35849]
# [0.5951806  0.2391103  0.1296885  0.10097177 0.11357866 0.16336882
#  0.26309831]
# [0.45536 0.19643 0.125   0.24107 0.17857 0.24107 0.38393]
# [0.61422336 0.27221993 0.16080114 0.13022578 0.13935447 0.18154298
#  0.29303377]
# [0.43878  0.091837 0.071429 0.10204  0.16327  0.2551   0.43878 ]
# [0.63179306 0.30348067 0.20354842 0.18129946 0.19709495 0.24607593
#  0.35242154]
# [0.53774 0.27358 0.12264 0.11321 0.14151 0.20755 0.36792]
# [0.655056   0.34218806 0.26156008 0.25231459 0.27430382 0.31459054
#  0.39995107]
# [0.45263 0.23158 0.18947 0.24211 0.33684 0.27368 0.34737]
# [0.67291989 0.37375712 0.29627489 0.28541119 0.29964258 0.33357896
#  0.41933171]
# [0.81319 0.56044 0.40659 0.38462 0.49451 0.53846 0.50549]
# [0.96098995 0.91593783 0.90163279 0.88981338 0.88424688 0.88691116
#  0.90306423]
# Text(0.5, 0.98, 'correlator of the sigma field for a 3us Dilila ramp with a 600ns Rabi ramp')

# %%
full_data_sim_3 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_29/Overlap2022_11_30_17_53_13_L15_1',delimiter=',')
full_data_sim_5 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_29/Overlap2022_11_30_16_50_41_L15_1',delimiter=',')

# %%
tlist = np.array([1.34,1.51,1.68,1.85,2.02,3])+0.6
print('3us scan')
t_id = []
for i in range(0,len(tlist)):
    temp = np.argmin(abs(full_data_sim_3[0]-tlist3[i]))
    t_id.append(temp)
    print('Real Time(with rabi)(us) = %.3f' %(full_data_sim_3[0,temp])+' overlap = %.3f' %full_data_sim_3[5,temp])
# Out:
# 3us scan
# Real Time(with rabi)(us) = 1.931 overlap = 0.972
# Real Time(with rabi)(us) = 2.085 overlap = 0.971
# Real Time(with rabi)(us) = 2.290 overlap = 0.972
# Real Time(with rabi)(us) = 2.443 overlap = 0.975
# Real Time(with rabi)(us) = 2.597 overlap = 0.980
# Real Time(with rabi)(us) = 3.570 overlap = 0.960

# %%
tlist5 = np.array([2.2, 3.1-0.6, 3.4-0.6, 3.1, 4-0.6,  5.])+0.6
#print(tlist)
t_id = []
print('5us scan')
for i in range(0,len(tlist)):
    temp = np.argmin(abs(full_data_sim_5[0]-tlist5[i]))
    t_id.append(temp)
    print('Real Time(with rabi)(us) = %.3f' %(full_data_sim_5[0,temp])+' overlap = %.3f' %full_data_sim_5[5,temp])
# Out:
# 5us scan
# Real Time(with rabi)(us) = 2.802 overlap = 0.991
# Real Time(with rabi)(us) = 3.109 overlap = 0.991
# Real Time(with rabi)(us) = 3.416 overlap = 0.993
# Real Time(with rabi)(us) = 3.723 overlap = 0.994
# Real Time(with rabi)(us) = 3.979 overlap = 0.993
# Real Time(with rabi)(us) = 5.566 overlap = 0.991

# %%
plt.plot(1)
plt.ylabel('$\langle a \\rangle$')
# Out:
# Text(0, 0.5, '$\\langle a \\rangle$')

# %%
fig, ax = plt.subplots() 
ax.scatter(2*data_exp5[0],data_exp5[4],marker='o',label = 'Exp')
ax.scatter(2*data_exp5[0],data_sim_5[2],marker='D',label = 'Sim')
ax.plot(2*data_exp5[0],data_exp5[4])
   # ax[i//3,i%3].set_yscale('log')
ax.legend(loc = 'upper right',prop={'size': 15})
   #ax[i//3,i%3].set_ylim((0.01,1))
ax.set_xlabel('d',fontsize=15)
ax.set_ylabel('$\langle \sigma_{mid-d/2} \sigma_{mid+d/2} \\rangle$  ',fontsize= 15,rotation = 0)

ax.yaxis.set_label_coords(0.05,1.02)
ax.set_xticks(2*data_exp5[0])
ax.tick_params(axis='both', which='major',direction='in', labelsize=15)

ax.text(5,0.68,'2.8$\mu$s LILA ramp',fontsize = 15)
plt.savefig('crit_5us.svg',transparent = True)

# %%
data_exp5
# Out:
# array([[1.0000e+00, 2.0000e+00, 3.0000e+00, 4.0000e+00, 5.0000e+00,
#         6.0000e+00, 7.0000e+00],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00],
#        [3.8000e-01, 7.3333e-02, 2.0000e-02, 6.0000e-02, 1.4000e-01,
#         2.2000e-01, 3.4667e-01],
#        [4.2949e-01, 1.6026e-01, 8.3333e-02, 3.2051e-02, 8.9744e-02,
#         1.6026e-01, 2.5000e-01],
#        [4.3624e-01, 2.2148e-01, 1.6779e-01, 1.0738e-01, 1.6107e-01,
#         1.6107e-01, 2.4832e-01],
#        [5.5782e-01, 2.7211e-01, 1.2245e-01, 1.5646e-01, 1.7007e-01,
#         1.6327e-01, 2.6531e-01],
#        [4.1549e-01, 1.6901e-01, 1.4789e-01, 8.4507e-02, 7.7465e-02,
#         1.9014e-01, 3.8732e-01],
#        [7.2078e-01, 4.8701e-01, 3.8312e-01, 3.7662e-01, 2.9870e-01,
#         3.1169e-01, 4.2857e-01],
#        [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00],
# ...

# %%
full_data_sim_32 = (np.loadtxt('C:/Users/wangy/Downloads/Ring8us_th.csv',delimiter=',')).transpose()
full_data_exp_32 = (np.loadtxt('C:/Users/wangy/Downloads/Ring8us_exp.csv',delimiter=',')).transpose()

# %%
full_data_exp_32
# Out:
# array([[ 1.50000000e+00,  2.50000000e+00,  3.50000000e+00,
#          4.50000000e+00,  5.50000000e+00,  6.50000000e+00,
#          7.50000000e+00,  8.50000000e+00,  9.50000000e+00,
#          1.05000000e+01,  1.15000000e+01,  1.25000000e+01,
#          1.35000000e+01,  1.45000000e+01,  1.55000000e+01,
#          1.65000000e+01,  1.75000000e+01,  1.85000000e+01,
#          1.95000000e+01,  2.05000000e+01,  2.15000000e+01,
#          2.25000000e+01,  2.35000000e+01,  2.45000000e+01,
#          2.55000000e+01,  2.65000000e+01,  2.75000000e+01,
#          2.85000000e+01,  2.95000000e+01,  3.05000000e+01,
#          3.15000000e+01,  3.25000000e+01],
#        [ 2.32249945e-01,  1.04091017e-01,  5.40662595e-02,
#          6.01502898e-02,  5.49465412e-02,  4.67993508e-02,
#          1.14459544e-02,  1.85569799e-02, -4.83925690e-03,
#          2.69930128e-02, -4.03233201e-03,  2.85862309e-03,
#         -1.15880832e-02, -1.08590999e-02, -2.93197990e-03,
# ...

# %%
fig, ax = plt.subplots() 
ax.errorbar(full_data_exp_32[0],full_data_exp_32[1],full_data_exp_32[2],label = 'Exp')
ax.scatter(full_data_sim_32[0],full_data_sim_32[1],color='#ff7f0e',marker='D',label = 'Sim')
ax.legend(loc = 'upper right',prop={'size': 15})

ax.set_xlabel('d',fontsize=15)
ax.set_ylabel('$\langle \sigma_0 \sigma_d \\rangle$  ',fontsize= 15,rotation = 0)

ax.yaxis.set_label_coords(0.05,1.02)

ax.tick_params(axis='both', which='major',direction='in', labelsize=15)
ax.set_title(' 8 us LILA ramp',fontsize = 15)
plt.savefig('crit_32sites.svg',transparent = True)
