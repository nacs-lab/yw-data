# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from itertools import product
from scipy.optimize import curve_fit

# %% [markdown]
# # benchmark

# %%
data_exp = np.loadtxt('./rydberg_data/3x5Data_8_25_slow.csv',delimiter=',')

# %%
data = {}
for params in [(5,3,0.0,-4,4,0.649,2.,0.05,0)]:
    data[params] = {}
    data[params]['z'] = np.loadtxt("./rydberg_data/z_L%d_%d_den%.3f_delta%.1f_%.1f_omega%.3f_ramptime%.3f_dt%.3f_No%d.csv"%params,delimiter=',')
   # temp = np.loadtxt("./rydberg_data/zz_L%d_%d_den%.3f_delta%.1f_%.1f_omega%.3f_ramptime%.3f_dt%.3f_No%d.csv"%params,delimiter=',')
   # data[params]['zz'] = np.reshape(temp,(temp.shape[0],params[0]*params[1],params[0]*params[1]))

# %%
temp = [[-1.0], [-0.5903239493562947], [0.30303526963277355], [0.948101903684032], [0.8163392507171847], [0.01570731731182201], [-0.79779443953857], [-0.9576216459576228], [-0.3328195445229885], [0.564678950066075], [0.9995065603657313], [0.6153863701791737], [-0.27295193551732216], [-0.9376464992972344], [-0.8340784336131732], [-0.04710645070964642], [0.778462301567021], [0.966196331281716], [0.36227536670454974], [-0.5384766808266563], [-0.9980267284282713], [-0.6398414789511822], [0.24259923079540252], [0.9262657510190648], [0.850994481794695], [0.0784590957278507], [-0.7583619152887181], [-0.9738174974771302], [-0.39137366683720837], [0.5117430001143393], [0.9955619646030796], [0.663665141432464], [-0.21200710992204747], [-0.9139708902740582], [-0.8670707011644938], [-0.1097343110910532], [0.7375131173581684], [0.9804776233729462], [0.42008572841181396], [-0.4845042908443901], [-0.9921147013144765], [-0.6868338465444153], [0.1812057636271278], [0.9007740506053936], [0.8822912264349579], [0.14090123193759319], [-0.7159364830218236], [-0.9861701362289906], [-0.4483832160900424], [0.4567874343342892], [0.9876883405951361], [0.7093247295722825], [-0.15022558912074496], [-0.8866882557005509], [-0.8966410367852417], [-0.17192910027942226], [0.6936533058127954], [0.9908894182223403], [0.47623820366795117], [-0.4286197837751157], [-0.9822872507286862], [-0.7311155947298739], [0.11909716009485538], [0.8717274065385017], [0.9101059706850017], [0.2027872953565273], [-0.6706855765367086], [-0.9946308119914341], [-0.5036232016357747], [0.4000291372372501], [0.9759167619387439], [0.7521849370641221], [-0.0878511965507267], [-0.8559062676711242], [-0.9226727398701213], [-0.23344536385592218], [0.6470559615694309], [0.997390625232325], [0.5305111843067494], [-0.37104371023703414], [-0.9685831611286267], [-0.7725119636778761], [0.05651853448200583], [0.8392404526523717], [0.9343289424566193], [0.26387304996539196], [-0.6227877804880972], [-0.9991661343425414], [-0.5568756164882052], [0.3416921078914641], [0.9602936856769378], [0.7920766142499807], [-0.025130095443315625], [-0.8217464086295783], [-0.9450630751798127], [-0.2940403252323255], [0.597904983057501], [0.9999555871089506], [0.5826904796685952], [-0.31200329668839266], [-0.9510565162951466]]

# %%
plt.plot(np.arange(len(temp))*0.05,temp)

# %%
params = (5,3,0.0,-4,4,0.649,2.,0.05,0)
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
plt.subplots_adjust(wspace=0.5,hspace=0.5)
for i in range(15):
    #print(temp[:,i])
    ax[int(i/3),i%3].errorbar(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,yerr=(data_exp[i+1+15,:]+data_exp[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[int(i/3),i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,ls='-',label='numerics')
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[int(i/3),i%3].set_ylim([0,1])
    ax[int(i/3),i%3].set_xticks([0,1,2,3])
    ax[int(i/3),i%3].set_yticks([0,0.2,0.4,0.6,0.8,1])

    #ax[i/3,i%3].set_xlim([0,1])
    ax[int(i/3),i%3].grid()

    ax[int(i/3),i%3].set_xlabel('Time(us)')
    ax[int(i/3),i%3].set_ylabel('G survival')
ax[4,2].legend(handlelength=0.5)

plt.show()

# %%
params = (5,3,0.0,-8*2*np.pi,8*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
#fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    plt.plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,ls='-',label='%d,%d'%(i/5,i%5))
    #ax[i/3,i%3].set_xticks([0,0.5,1])
plt.show()

# %%
params = ((5,3,0.0,-8,8,0.748,1.,0.05,0))
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[int(i/3),i%3].errorbar(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,yerr=(data_exp[i+1+15,:]+data_exp[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[int(i/3),i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[int(i/3),i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[int(i/3),i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
params = (4,3,0.0,-4*2*np.pi,4*2*np.pi,1.,0.05,0)
dt = params[6]
temp2_1 = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=4,figsize=(7,10))
for i in range(12):
    #ax[i/3,i%3].errorbar(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,yerr=(data_exp[i+1+15,:]+data_exp[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
ax[4,2].legend(handlelength=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-8fc0b59a58f0> in <module>
#       1 params = (4,3,0.0,-4*2*np.pi,4*2*np.pi,1.,0.05,0)
#       2 dt = params[6]
# ----> 3 temp2_1 = data[params]['z']
#       4 fig,ax = plt.subplots(ncols=3,nrows=4,figsize=(7,10))
#       5 for i in range(12):
#
# KeyError: (4, 3, 0.0, -25.132741228718345, 25.132741228718345, 1.0, 0.05, 0)

# %%
params = (5,3,0.0,-1*2*np.pi,4*2*np.pi,1.,0.05,0)
dt = params[6]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[i/3,i%3].errorbar(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,ls='-',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,ls='-',label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
params = (5,3,0.0,-4*2*np.pi,4*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[i/3,i%3].errorbar(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,yerr=(data_exp[i+1+15,:]+data_exp[15-i+15,:])/2,ls='-',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,ls='-',label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
params = (5,3,0.0,-4*2*np.pi,4*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[i/3,i%3].plot(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,ls='-',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,ls='-',label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
params = (5,3,0.0,-1*2*np.pi,4*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[i/3,i%3].errorbar(data_exp[0,:],(data_exp[i+1,:]+data_exp[15-i,:])/2,yerr=(data_exp[i+1+15,:]+data_exp[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
    
params = (5,3,0.0,-1*2*np.pi,4*2*np.pi,1.,0.05,0)
dt = params[6]
temp = data[params]['z']
for i in range(15):
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
    
    
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
params = (5,3,0.0,-4*2*np.pi,4*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[i/3,i%3].errorbar(data_exp1[0,:],(data_exp1[i+1,:]+data_exp1[15-i,:])/2,yerr=(data_exp1[i+1+15,:]+data_exp1[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
    
params = (5,3,0.0,-8*2*np.pi,8*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
for i in range(15):
    #ax[i/3,i%3].errorbar(data_exp1[0,:],(data_exp1[i+1,:]+data_exp1[15-i,:])/2,yerr=(data_exp1[i+1+15,:]+data_exp1[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
    
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
params = (5,3,0.0,-4*2*np.pi,4*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
fig,ax = plt.subplots(ncols=3,nrows=5,figsize=(7,10))
for i in range(15):
    ax[i/3,i%3].errorbar(data_exp1[0,:],(data_exp1[i+1,:]+data_exp1[15-i,:])/2,yerr=(data_exp1[i+1+15,:]+data_exp1[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
    
params = (5,3,0.0,-8*2*np.pi,8*2*np.pi,1.495*2*np.pi,1.,0.05,0)
dt = params[7]
temp = data[params]['z']
for i in range(15):
    #ax[i/3,i%3].errorbar(data_exp1[0,:],(data_exp1[i+1,:]+data_exp1[15-i,:])/2,yerr=(data_exp1[i+1+15,:]+data_exp1[15-i+15,:])/2,ls='--',marker='.',label='experiment')
    ax[i/3,i%3].plot(np.arange(len(temp[:,i]))*dt,1-(temp[:,i]+1)/2,label='numerics,twice freq')
    
    #plt.legend(handlelength=0.5,ncol=3)
    #plt.text(20,0.75,'size=3*5',fontsize=25)
    ax[i/3,i%3].set_ylim([0,1])
    #ax[i/3,i%3].set_xlim([0,1])
    ax[i/3,i%3].set_yticks([0,0.5,1.0])
    #ax[i/3,i%3].set_xticks([0,0.5,1])
    
ax[4,2].legend(handlelength=0.5)
plt.show()

# %%
(5*1.76e-4)**-0.5
# Out:
# 33.70999312316211
