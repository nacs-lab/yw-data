# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_27_01_01_24_L19_1', delimiter = ',')

# %%
ig, ax = plt.subplots(2, 3, figsize=(15,5))
#fig.suptitle('19 Atoms')
MS = 1
LS = ''
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,2].plot(data[0],data[1],marker='o',markersize=MS,ls=LS)
ax[0,2].set_xlabel('t')
ax[0,2].set_ylabel('detuning')
ax[0,0].plot(data[0],data[2],marker='o',markersize=MS,ls=LS)
ax[0,0].set_xlabel('t')
ax[0,0].set_xl('t')
ax[0,0].set_ylabel('overlap with GGG')
ax[0,1].plot(data[0],data[3],marker='o',markersize=MS,ls=LS)
ax[0,1].set_xlabel('t')
ax[0,1].set_ylabel('overlap with AFM')
ax[1,0].plot(data[0],data[4],marker='o',markersize=MS,ls=LS)
ax[1,0].set_xlabel('t')
ax[1,0].set_ylabel('overlap with Ground state')

ax[1,1].plot(data[0],data[5],marker='o',markersize=MS,ls=LS)
ax[1,1].set_xlabel('t')
ax[1,1].set_ylabel('overlap with 1st Excited state')

ax[1,2].plot(data[0],data[7],marker='o',markersize=MS,ls=LS)
ax[1,2].set_xlabel('t')
ax[1,2].set_ylabel('overlap with 3rd excited state')
# Out:
# Text(0, 0.5, 'overlap with 3rd excited state')

# %%
data1 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_26_18_35_15_L7_1', delimiter = ',')
data2 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_26_21_57_18_L7_1', delimiter = ',')
data3 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/11_26/Overlap2022_11_26_22_00_14_L7_1', delimiter = ',')



fig, ax = plt.subplots(2, 3, figsize=(15,5))
#fig.suptitle('19 Atoms')
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,2].plot(data1[0],data1[1],marker='o')
#ax[0,2].plot(data[0],data[1],marker='o')
ax[0,2].plot(data3[0],data3[1],marker='o')

ax[0,2].set_xlabel('t')
ax[0,2].set_ylabel('detuning')
ax[0,0].plot(data1[0],data1[2],marker='o')
ax[0,0].set_xlabel('t')
ax[0,0].set_ylabel('overlap with GGG')
ax[0,1].plot(data1[0],data1[3],marker='o')
ax[0,1].set_xlabel('t')
ax[0,1].set_ylabel('overlap with AFM')
ax[1,0].plot(data1[0],data1[4],marker='o')
ax[1,0].plot(data[0],data[4],marker='o')
ax[1,0].plot(data2[0],data2[4],marker='o')
ax[1,0].plot(data3[0],data3[4],marker='.')

ax[1,0].set_xlabel('t')
ax[1,0].set_ylabel('overlap with Ground state')

ax[1,1].plot(data1[0],data1[5],marker='o')
ax[1,1].set_xlabel('t')
ax[1,1].set_ylabel('overlap with 1st Excited state')
ax[1,2].plot(data1[0],data1[6],marker='o')
ax[1,2].set_xlabel('t')
ax[1,2].set_ylabel('overlap with 3rd excited state')
# Out:
# Text(0, 0.5, 'overlap with 3rd excited state')
