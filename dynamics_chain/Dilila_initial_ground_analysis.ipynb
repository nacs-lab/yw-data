# %%
import numpy as np
import matplotlib.pyplot as plt
data = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_1/Overlap02022_12_01_10_35_50_L15_1', delimiter = ',')
# startig from all atoms in the ground state
data_2 = np.loadtxt('C:/Users/wangy/Rydberg simulation/rydberg_data/12_1/Overlap12022_12_01_10_35_50_L15_1', delimiter = ',')
# starting from the system ground state

# %%
fig, ax = plt.subplots(2, 2, figsize=(15,5))
#fig.suptitle('19 Atoms')
MS = 1
LS = '-'
plt.subplots_adjust(wspace=0.5,hspace=0.5)
ax[0,0].plot(data[0],data[1],marker='o',markersize=MS,ls=LS)
ax[0,0].plot(data_2[0],data_2[1],marker='o',markersize=MS,ls=LS)
ax[0,0].set_xlabel('t(us)')
ax[0,0].set_ylabel('Detuning(MHz)')

ax[0,1].plot(data[0],data[2],marker='o',ls=LS)
ax[0,1].plot(data_2[0],data_2[2],marker='o',markersize=MS,ls=LS)
ax[0,1].set_xlabel('t(us)')
ax[0,1].set_ylabel('overlap with FM')

ax[1,0].plot(data[0],data[3],marker='o',markersize=MS,ls=LS,label ='initialized in FM')
ax[1,0].plot(data_2[0],data_2[3],marker='o',markersize=MS,ls=LS,label = 'initialized in the Ground state')
ax[1,0].set_xlabel('t(us)')
ax[1,0].set_ylabel('overlap with AFM')

ax[1,1].plot(data[0],data[4],marker='o',markersize=MS,ls=LS)
ax[1,1].plot(data_2[0],data_2[4],marker='o',markersize=MS,ls=LS)
ax[1,1].set_xlabel('t(us)')
ax[1,1].set_ylabel('overlap with Ground state')


fig.legend()
